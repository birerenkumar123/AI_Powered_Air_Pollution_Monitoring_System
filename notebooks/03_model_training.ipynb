# %% [markdown]
# # Model Training
#
# Train and evaluate trading prediction models

# %%
import pandas as pd
import sys
sys.path.append('../src')

from models.train import *
from models.evaluate import *

# Load training data
# X_train, y_train = load_training_data()
# Train model and evaluate performance
