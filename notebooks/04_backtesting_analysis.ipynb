# %% [markdown]
# # Backtesting Analysis
#
# Backtest strategy and analyze performance metrics

# %%
import pandas as pd
import sys
sys.path.append('../src')

from backtesting.backtest import *

# Run backtest
# results = run_backtest()
# Generate report and visualizations
