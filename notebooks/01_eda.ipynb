# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# Initial exploration of stock market data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
# df = pd.read_csv('../data/raw/stock_data.csv')
# df.head()
